# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cleaned_data.csv")

# %%
df.head()
# Out:
#            Job Title              Salary Estimate  \
# 0  Software Engineer  $89K-$175K (Glassdoor est.)
# 1  Software Engineer  $89K-$175K (Glassdoor est.)
# 2  Software Engineer  $89K-$175K (Glassdoor est.)
# 3  Software Engineer  $89K-$175K (Glassdoor est.)
# 4  Software Engineer  $89K-$175K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  About Agari\n\n\nFounded by thought leaders of...     4.2
# 1  Job Description\n\nCSI’s Payments Software Eng...     4.0
# 2  Company Overview\n\n\nDematic is a leading sup...     3.8
# 3  Description:Do you have a commitment to succes...     3.8
# 4  Who we are...\n\n\nVerra Mobility is a global ...     3.9
#
#           Company Name         Location     Headquarters  \
# 0              Agari\n    San Mateo, CA  Foster City, CA
# 1  Computer Services\n   Valparaiso, IN      Paducah, KY
# 2            Dematic\n   New Berlin, WI      Atlanta, GA
# 3    Lockheed Martin\n    Englewood, CO     Bethesda, MD
# ...

# %%
df.describe()
# Out:
#            Rating      Founded  Competitors  min_salary  max_salary  \
# count  479.000000   479.000000   479.000000  479.000000  479.000000
# mean     3.787891  1872.507307     1.075157   70.693111  112.027140
# std      0.957715   459.657522     1.337654   25.441289   25.090324
# min     -1.000000    -1.000000     0.000000   34.000000   74.000000
# 25%      3.500000  1970.000000     0.000000   48.000000   91.000000
# 50%      3.900000  1994.000000     0.000000   66.000000  110.000000
# 75%      4.350000  2004.000000     3.000000   89.000000  124.000000
# max      5.000000  2019.000000     4.000000  119.000000  175.000000
#
#        avg_salary  same_state  age (2020)   python_yn     java_yn      aws_yn  \
# count  479.000000  479.000000  479.000000  479.000000  479.000000  479.000000
# mean    91.360125    0.659708   33.517745    0.281837    0.582463    0.267223
# std     23.814271    0.474303   35.324307    0.450365    0.493668    0.442973
# ...

# %%
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df['age (2020)'].hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column = ['age (2020)','avg_salary','desc_len'])

# %% [markdown]
# df

# %%
df[['age (2020)','avg_salary','Rating','desc_len','Competitors']].corr()
# Out:
#              age (2020)  avg_salary    Rating  desc_len  Competitors
# age (2020)     1.000000   -0.061573  0.033659  0.135147     0.311134
# avg_salary    -0.061573    1.000000 -0.060647 -0.026454    -0.007484
# Rating         0.033659   -0.060647  1.000000  0.001310    -0.008923
# desc_len       0.135147   -0.026454  0.001310  1.000000     0.199177
# Competitors    0.311134   -0.007484 -0.008923  0.199177     1.000000

# %%
cmap = sns.diverging_palette(220,10,as_cmap=True)
sns.heatmap(df[['age (2020)','Rating','avg_salary','desc_len','Competitors']].corr(),vmax = .6,center = 0,
            cmap = cmap,square = True,linewidths = .5,cbar_kws={"shrink":.5})

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'min_salary', 'max_salary', 'avg_salary', 'job_state', 'head_state',
#        'same_state', 'age (2020)', 'python_yn', 'java_yn', 'aws_yn', 'api_yn',
#        'job_simple', 'seniority', 'desc_len', 'Company'],
#       dtype='object')

# %%
df_cat = df[['job_state','head_state','same_state','python_yn','java_yn','aws_yn','api_yn','job_simple','seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print("%s" % (i))
    chart = sns.barplot(x=cat_num.index,y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
    plt.show()
# Out:
# job_state
# head_state
# same_state
# python_yn
# java_yn
# aws_yn
# api_yn
# job_simple
# seniority

# %%
pd.pivot_table(df,index=['job_simple','seniority'],values='avg_salary')
# Out:
#                       avg_salary
# job_simple seniority
# database   na          90.812500
# front_end  na          90.000000
#            senior      75.500000
# others     junior     110.000000
#            na          94.741379
#            senior      83.000000
# software   junior      85.600000
#            na          89.888889
#            senior      94.295918
# technical  na          94.500000
#            senior      77.000000

# %%
pd.pivot_table(df,index='job_state',values='avg_salary').sort_values('avg_salary',ascending= False)
# Out:
#            avg_salary
# job_state
#  PR        134.000000
#  KY        112.000000
#  IA        106.250000
#  IL        101.675000
#  WV        100.750000
#  SC        100.642857
#  NE        100.166667
#  NC         98.722222
#  CT         96.000000
#  CA         95.902439
#  NJ         95.187500
#  NH         94.833333
#  MO         93.500000
#  UT         92.375000
#  NY         91.775000
#  AL         91.692308
#  CO         91.593750
#  TX         91.533333
#  MA         91.375000
#  VA         91.198413
#  MD         90.821429
#  WA         90.105263
#  OH         90.041667
#  AZ         86.500000
#  FL         86.386364
#  OK         85.375000
#  MI         84.823529
#  WI         84.045455
#  IN         83.500000
#  MN         82.000000
#  OR         81.100000
#  ID         80.000000
#  GA         78.722222
#  TN         77.000000
#  PA         76.916667
#  LA         75.500000
#  VT         64.500000
#  DE         54.000000

# %%
pd.set_option("display.max_rows",None)
pd.pivot_table(df,index=['job_state','job_simple'],values='avg_salary',aggfunc='count').sort_values('job_state',ascending= False)
# Out:
#                       avg_salary
# job_state job_simple
#  WV       software             2
#  WI       software             6
#           others               4
#           front_end            1
#  WA       database             4
#           software            13
#           others               2
#  VT       database             1
#  VA       technical            1
#           software            54
#           others               6
#           database             2
#  UT       software             8
#  TX       software            12
#           others               3
#  TN       software             1
#  SC       software             7
#  PR       software             1
#  PA       software            12
#  OR       software             4
#           others               1
#  OK       software             4
#  OH       software             9
#           others               3
#  NY       others               6
#           technical            1
# ...

# %%
pd.pivot_table(df[df.job_simple=='software'],index=['job_state','job_simple'],values='avg_salary').sort_values('avg_salary',ascending= False)
# Out:
#                       avg_salary
# job_state job_simple
#  PR       software    134.000000
#  IA       software    108.000000
#  NJ       software    101.071429
#  WV       software    100.750000
#  IL       software    100.750000
#  SC       software    100.642857
#  NE       software    100.166667
#  CA       software     96.600000
#  NH       software     94.833333
#  CO       software     93.892857
#  MO       software     93.500000
#  MD       software     92.384615
#  UT       software     92.375000
#  NC       software     91.250000
#  MA       software     91.173913
#  TX       software     90.916667
#  AL       software     90.500000
#  NY       software     90.125000
#  WA       software     88.807692
#  VA       software     88.703704
#  AZ       software     86.500000
#  OH       software     86.444444
#  WI       software     85.916667
#  FL       software     85.647059
#  OK       software     85.375000
#  OR       software     84.750000
# ...

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /Users/cyt/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/cyt/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()
